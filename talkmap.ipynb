# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# %pip install --upgrade getorg geopy ipyleaflet
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (0.3.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: geopy in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (2.4.1)
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pygithub in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from getorg) (2.6.1)
# Requirement already satisfied: retrying in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from getorg) (1.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from geopy) (2.0)
# Requirement already satisfied: branca>=0.5.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipyleaflet) (0.8.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipyleaflet) (8.1.1)
# Collecting jupyter-leaflet<0.21,>=0.20 (from ipyleaflet)
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet)
#   Downloading traittypes-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipyleaflet) (2024.4.0)
# Requirement already satisfied: jinja2>=3 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.9)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pygithub->getorg) (2.31.0)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pygithub->getorg) (4.7.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pygithub->getorg) (2.1.0)
# Requirement already satisfied: Deprecated in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pygithub->getorg) (1.2.18)
# Requirement already satisfied: backcall in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: decorator in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.2)
# Requirement already satisfied: colorama in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (2.1.3)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (45.0.4)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2023.11.17)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from Deprecated->pygithub->getorg) (1.17.2)
# Requirement already satisfied: pycparser in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\dykua\anaconda3\envs\dmml\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.16.0)
# Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 4.5 MB/s eta 0:00:00
# Downloading traittypes-0.2.3-py2.py3-none-any.whl (8.1 kB)
# Installing collected packages: traittypes, jupyter-leaflet, ipyleaflet
# Successfully installed ipyleaflet-0.20.0 jupyter-leaflet-0.20.0 traittypes-0.2.3
# WARNING: Error parsing dependencies of prometheus-client: [Errno 2] No such file or directory: 'c:\\users\\dykua\\anaconda3\\envs\\dmml\\lib\\site-packages\\prometheus_client-0.19.0.dist-info\\METADATA'

# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Traceback (most recent call last):
#   File "C:\Users\dykua\anaconda3\envs\DMML\Scripts\jupyter-nbextension-script.py", line 9, in <module>
#     sys.exit(main())
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\jupyter_core\application.py", line 285, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 972, in start
#     super().start()
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\jupyter_core\application.py", line 274, in start
#     self.subapp.start()
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 882, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 855, in toggle_nbextension_python
#     return toggle(module,
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 470, in enable_nbextension_python
#     return _set_nbextension_state_python(True, module, user, sys_prefix,
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 368, in _set_nbextension_state_python
#     m, nbexts = _get_nbextension_metadata(module)
#   File "C:\Users\dykua\anaconda3\envs\DMML\lib\site-packages\notebook\nbextensions.py", line 1109, in _get_nbextension_metadata
#     raise KeyError(
# KeyError: 'The Python module ipyleaflet is not a valid nbextension, it is missing the `_jupyter_nbextension_paths()` method.'

# %%
g = glob.glob("C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\*.md")
g
# Out:
# ['C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\Banff.md',
#  'C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\Chatham.md',
#  'C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\NRC.md',
#  'C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\RMMC2016.md',
#  'C:\\Users\\dykua\\github\\dykuang.github.io\\_talks\\Uottawa.md']

# %%
geocoder = Nominatim(user_agent="my-application")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Banff, Alberta, Canada
#  Banff, Alberta, T1L 1A6, Canada
# Pittsburgh, Pennsylvania, USA
#  PGH, Allegheny County, Pennsylvania, USA
# 1920 Research Private, Ottawa, Ontario, Canada
#  NRC Flight Research Laboratory, 1920, Research Private, NRC, South Keys, Gloucester-Southgate, Gloucester, Ottawa, Ontario, K1V 7N9, Canada
# Laramie, WY
#  Laramie, Albany County, Wyoming, USA
# Ottawa, Ontario, Canada
#  Ottawa, Eastern Ontario, Ontario, K1P 1J1, Canada

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'

# %%
location_dict
# Out:
# {'1920 Research Private, Ottawa, Ontario, Canada': Location(NRC Flight Research Laboratory, 1920, Research Private, NRC, South Keys, Gloucester-Southgate, Gloucester, Ottawa, Ontario, K1V 7N9, Canada, (45.325311, -75.6659056114435, 0.0)),
#  'Banff, Alberta, Canada': Location(Banff, Alberta, T1L 1A6, Canada, (51.1777781, -115.5682504, 0.0)),
#  'Laramie, WY': Location(Laramie, Albany County, Wyoming, USA, (41.311367, -105.591101, 0.0)),
#  'Ottawa, Ontario, Canada': Location(Ottawa, Eastern Ontario, Ontario, K1P 1J1, Canada, (45.421106, -75.690308, 0.0)),
#  'Pittsburgh, Pennsylvania, USA': Location(PGH, Allegheny County, Pennsylvania, USA, (40.4416941, -79.9900861, 0.0))}
